# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv'

# %%
# !wget $data -O data-week-3.csv
# Out:
# --2022-09-27 00:32:58--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: 'data-week-3.csv'
#
# data-week-3.csv     100%[===================>]   1.36M  1.28MB/s    in 1.1s
#
# 2022-09-27 00:33:00 (1.28 MB/s) - 'data-week-3.csv' saved [1423529/1423529]

# %%
df = pd.read_csv('data-week-3.csv')

# %%
df.iloc[0].index
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(0)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df['rooms_per_household'] = df['total_rooms'] / df['households']

# %%
df['bedrooms_per_room'] = df['total_bedrooms'] / df['total_rooms']

# %%
df['population_per_household'] = df['population'] / df['households']

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df.dtypes
# Out:
# longitude                   float64
# latitude                    float64
# housing_median_age          float64
# total_rooms                 float64
# total_bedrooms              float64
# population                  float64
# households                  float64
# median_income               float64
# median_house_value          float64
# ocean_proximity              object
# rooms_per_household         float64
# bedrooms_per_room           float64
# population_per_household    float64
# dtype: object

# %%
df.iloc[0].index
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'rooms_per_household',
#        'bedrooms_per_room', 'population_per_household'],
#       dtype='object')

# %%
corl = df[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income',
       'median_house_value', 'rooms_per_household',
       'bedrooms_per_room', 'population_per_household']]

# %%
corl.corr()
# Out:
#                           longitude  latitude  housing_median_age  \
# longitude                  1.000000 -0.924664           -0.108197
# latitude                  -0.924664  1.000000            0.011173
# housing_median_age        -0.108197  0.011173            1.000000
# total_rooms                0.044568 -0.036100           -0.361262
# total_bedrooms             0.068082 -0.065318           -0.317063
# population                 0.099773 -0.108785           -0.296244
# households                 0.055310 -0.071035           -0.302916
# median_income             -0.015176 -0.079809           -0.119034
# median_house_value        -0.045967 -0.144160            0.105623
# rooms_per_household       -0.027540  0.106389           -0.153277
# bedrooms_per_room          0.084836 -0.104112            0.125396
# population_per_household   0.002476  0.002366            0.013191
#
#                           total_rooms  total_bedrooms  population  households  \
# longitude                    0.044568        0.068082    0.099773    0.055310
# latitude                    -0.036100       -0.065318   -0.108785   -0.071035
# housing_median_age          -0.361262       -0.317063   -0.296244   -0.302916
# total_rooms                  1.000000        0.920196    0.857126    0.918484
# total_bedrooms               0.920196        1.000000    0.866266    0.966507
# population                   0.857126        0.866266    1.000000    0.907222
# households                   0.918484        0.966507    0.907222    1.000000
# median_income                0.198050       -0.007295    0.004834    0.013033
# median_house_value           0.134153        0.049148   -0.024650    0.065843
# rooms_per_household          0.133798        0.002717   -0.072213   -0.080598
# bedrooms_per_room           -0.174583        0.122205    0.031397    0.059818
# population_per_household    -0.024581       -0.028019    0.069863   -0.027309
#
#                           median_income  median_house_value  \
# longitude                     -0.015176           -0.045967
# latitude                      -0.079809           -0.144160
# housing_median_age            -0.119034            0.105623
# total_rooms                    0.198050            0.134153
# total_bedrooms                -0.007295            0.049148
# population                     0.004834           -0.024650
# households                     0.013033            0.065843
# median_income                  1.000000            0.688075
# median_house_value             0.688075            1.000000
# rooms_per_household            0.326895            0.151948
# bedrooms_per_room             -0.573836           -0.238759
# population_per_household       0.018766           -0.023737
#
#                           rooms_per_household  bedrooms_per_room  \
# longitude                           -0.027540           0.084836
# latitude                             0.106389          -0.104112
# housing_median_age                  -0.153277           0.125396
# total_rooms                          0.133798          -0.174583
# total_bedrooms                       0.002717           0.122205
# population                          -0.072213           0.031397
# households                          -0.080598           0.059818
# median_income                        0.326895          -0.573836
# median_house_value                   0.151948          -0.238759
# rooms_per_household                  1.000000          -0.387465
# bedrooms_per_room                   -0.387465           1.000000
# population_per_household            -0.004852           0.003047
#
#                           population_per_household
# longitude                                 0.002476
# latitude                                  0.002366
# housing_median_age                        0.013191
# total_rooms                              -0.024581
# total_bedrooms                           -0.028019
# population                                0.069863
# households                               -0.027309
# median_income                             0.018766
# median_house_value                       -0.023737
# rooms_per_household                      -0.004852
# bedrooms_per_room                         0.003047
# population_per_household                  1.000000

# %%
df.median_house_value = (df.median_house_value > df.median_house_value.mean()).astype(int)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252                   1
# 1          2401.0      1138.0         8.3014                   1
# 2           496.0       177.0         7.2574                   1
# 3           558.0       219.0         5.6431                   1
# 4           565.0       259.0         3.8462                   1
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603                   0
# 20636       356.0       114.0         2.5568                   0
# 20637      1007.0       433.0         1.7000                   0
# 20638       741.0       349.0         1.8672                   0
# 20639      1387.0       530.0         2.3886                   0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# 0            NEAR BAY             6.984127           0.146591
# 1            NEAR BAY             6.238137           0.155797
# 2            NEAR BAY             8.288136           0.129516
# 3            NEAR BAY             5.817352           0.184458
# 4            NEAR BAY             6.281853           0.172096
# ...               ...                  ...                ...
# 20635          INLAND             5.045455           0.224625
# 20636          INLAND             6.114035           0.215208
# 20637          INLAND             5.205543           0.215173
# 20638          INLAND             5.329513           0.219892
# 20639          INLAND             5.254717           0.221185
#
#        population_per_household
# 0                      2.555556
# 1                      2.109842
# 2                      2.802260
# 3                      2.547945
# 4                      2.181467
# ...                         ...
# 20635                  2.560606
# 20636                  3.122807
# 20637                  2.325635
# 20638                  2.123209
# 20639                  2.616981
#
# [20640 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Question 3 Mutual Information

# %%
df_full_train, df_test = train_test_split(df, test_size = 0.2, random_state=42)

# %%
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state=42)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (12384, 4128, 4128)

# %%
df_train = df_train.reset_index(drop=True)

# %%
df_val = df_val.reset_index(drop=True)

# %%
df_test = df_test.reset_index(drop=True)

# %%
y_train = df_train.median_house_value.values

# %%
y_val = df_val.median_house_value.values

# %%
y_test = df_test.median_house_value.values

# %%
del df_train['median_house_value']
del df_val['median_house_value']
del df_test['median_house_value']

# %%
from sklearn.metrics import mutual_info_score

# %%
round(mutual_info_score(df_full_train.median_house_value, df_full_train.ocean_proximity), 2)
# Out:
# 0.1

# %% [markdown]
# ## Question 4

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train.to_dict(orient='records')

# %%
train_dicts
# Out:
# [{'longitude': -119.67,
#   'latitude': 34.43,
#   'housing_median_age': 39.0,
#   'total_rooms': 1467.0,
#   'total_bedrooms': 381.0,
#   'population': 1404.0,
#   'households': 374.0,
#   'median_income': 2.3681,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.9224598930481283,
#   'bedrooms_per_room': 0.25971370143149286,
#   'population_per_household': 3.7540106951871657},
#  {'longitude': -118.32,
#   'latitude': 33.74,
#   'housing_median_age': 24.0,
#   'total_rooms': 6097.0,
#   'total_bedrooms': 794.0,
#   'population': 2248.0,
#   'households': 806.0,
#   'median_income': 10.1357,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 7.564516129032258,
#   'bedrooms_per_room': 0.13022798097424962,
#   'population_per_household': 2.7890818858560795},
#  {'longitude': -121.62,
#   'latitude': 39.13,
#   'housing_median_age': 41.0,
#   'total_rooms': 1317.0,
#   'total_bedrooms': 309.0,
#   'population': 856.0,
#   'households': 337.0,
#   'median_income': 1.6719,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 3.908011869436202,
#   'bedrooms_per_room': 0.23462414578587698,
#   'population_per_household': 2.540059347181009},
#  {'longitude': -118.63,
#   'latitude': 34.24,
#   'housing_median_age': 9.0,
#   'total_rooms': 4759.0,
#   'total_bedrooms': 924.0,
#   'population': 1884.0,
#   'households': 915.0,
#   'median_income': 4.8333,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.201092896174863,
#   'bedrooms_per_room': 0.19415843664635427,
#   'population_per_household': 2.059016393442623},
#  {'longitude': -122.3,
#   'latitude': 37.52,
#   'housing_median_age': 38.0,
#   'total_rooms': 2769.0,
#   'total_bedrooms': 387.0,
#   'population': 994.0,
#   'households': 395.0,
#   'median_income': 5.5902,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 7.010126582278481,
#   'bedrooms_per_room': 0.13976164680390032,
#   'population_per_household': 2.5164556962025317},
#  {'longitude': -118.11,
#   'latitude': 33.73,
#   'housing_median_age': 32.0,
#   'total_rooms': 1258.0,
#   'total_bedrooms': 333.0,
#   'population': 645.0,
#   'households': 334.0,
#   'median_income': 5.0476,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 3.7664670658682633,
#   'bedrooms_per_room': 0.2647058823529412,
#   'population_per_household': 1.9311377245508983},
#  {'longitude': -118.37,
#   'latitude': 34.14,
#   'housing_median_age': 21.0,
#   'total_rooms': 4670.0,
#   'total_bedrooms': 1161.0,
#   'population': 1914.0,
#   'households': 1094.0,
#   'median_income': 3.7986,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.26873857404022,
#   'bedrooms_per_room': 0.24860813704496787,
#   'population_per_household': 1.7495429616087752},
#  {'longitude': -118.39,
#   'latitude': 34.06,
#   'housing_median_age': 39.0,
#   'total_rooms': 3299.0,
#   'total_bedrooms': 831.0,
#   'population': 1649.0,
#   'households': 759.0,
#   'median_income': 3.3295,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.346508563899868,
#   'bedrooms_per_room': 0.25189451348893604,
#   'population_per_household': 2.1725955204216074},
#  {'longitude': -118.54,
#   'latitude': 34.3,
#   'housing_median_age': 22.0,
#   'total_rooms': 4423.0,
#   'total_bedrooms': 622.0,
#   'population': 1995.0,
#   'households': 582.0,
#   'median_income': 8.2159,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.599656357388316,
#   'bedrooms_per_room': 0.1406285326701334,
#   'population_per_household': 3.4278350515463916},
#  {'longitude': -119.23,
#   'latitude': 36.39,
#   'housing_median_age': 39.0,
#   'total_rooms': 1660.0,
#   'total_bedrooms': 349.0,
#   'population': 1061.0,
#   'households': 306.0,
#   'median_income': 1.4812,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.42483660130719,
#   'bedrooms_per_room': 0.21024096385542168,
#   'population_per_household': 3.4673202614379086},
#  {'longitude': -117.1,
#   'latitude': 32.64,
#   'housing_median_age': 29.0,
#   'total_rooms': 1578.0,
#   'total_bedrooms': 460.0,
#   'population': 1236.0,
#   'households': 461.0,
#   'median_income': 2.5658,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 3.422993492407809,
#   'bedrooms_per_room': 0.2915082382762991,
#   'population_per_household': 2.6811279826464207},
#  {'longitude': -118.14,
#   'latitude': 33.91,
#   'housing_median_age': 36.0,
#   'total_rooms': 1096.0,
#   'total_bedrooms': 204.0,
#   'population': 569.0,
#   'households': 201.0,
#   'median_income': 4.475,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.45273631840796,
#   'bedrooms_per_room': 0.18613138686131386,
#   'population_per_household': 2.8308457711442787},
#  {'longitude': -118.36,
#   'latitude': 33.96,
#   'housing_median_age': 21.0,
#   'total_rooms': 1802.0,
#   'total_bedrooms': 556.0,
#   'population': 1286.0,
#   'households': 557.0,
#   'median_income': 2.7284,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.2351885098743267,
#   'bedrooms_per_room': 0.30854605993340734,
#   'population_per_household': 2.3087971274685817},
#  {'longitude': -122.47,
#   'latitude': 37.73,
#   'housing_median_age': 50.0,
#   'total_rooms': 1653.0,
#   'total_bedrooms': 252.0,
#   'population': 641.0,
#   'households': 224.0,
#   'median_income': 10.6605,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 7.379464285714286,
#   'bedrooms_per_room': 0.15245009074410162,
#   'population_per_household': 2.861607142857143},
#  {'longitude': -121.45,
#   'latitude': 38.48,
#   'housing_median_age': 24.0,
#   'total_rooms': 1766.0,
#   'total_bedrooms': 340.0,
#   'population': 1028.0,
#   'households': 372.0,
#   'median_income': 3.5402,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.747311827956989,
#   'bedrooms_per_room': 0.19252548131370328,
#   'population_per_household': 2.763440860215054},
#  {'longitude': -121.0,
#   'latitude': 37.67,
#   'housing_median_age': 26.0,
#   'total_rooms': 90.0,
#   'total_bedrooms': 18.0,
#   'population': 47.0,
#   'households': 18.0,
#   'median_income': 1.125,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.0,
#   'bedrooms_per_room': 0.2,
#   'population_per_household': 2.611111111111111},
#  {'longitude': -122.04,
#   'latitude': 37.53,
#   'housing_median_age': 25.0,
#   'total_rooms': 4458.0,
#   'total_bedrooms': 922.0,
#   'population': 2998.0,
#   'households': 890.0,
#   'median_income': 3.9667,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.008988764044944,
#   'bedrooms_per_room': 0.20681920143562135,
#   'population_per_household': 3.3685393258426966},
#  {'longitude': -122.66,
#   'latitude': 39.02,
#   'housing_median_age': 16.0,
#   'total_rooms': 3715.0,
#   'total_bedrooms': 810.0,
#   'population': 943.0,
#   'households': 510.0,
#   'median_income': 1.7446,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 7.284313725490196,
#   'bedrooms_per_room': 0.2180349932705249,
#   'population_per_household': 1.8490196078431373},
#  {'longitude': -122.01,
#   'latitude': 39.21,
#   'housing_median_age': 50.0,
#   'total_rooms': 1592.0,
#   'total_bedrooms': 372.0,
#   'population': 781.0,
#   'households': 307.0,
#   'median_income': 2.2679,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.185667752442996,
#   'bedrooms_per_room': 0.23366834170854273,
#   'population_per_household': 2.543973941368078},
#  {'longitude': -121.29,
#   'latitude': 38.71,
#   'housing_median_age': 32.0,
#   'total_rooms': 1875.0,
#   'total_bedrooms': 361.0,
#   'population': 1027.0,
#   'households': 343.0,
#   'median_income': 3.5769,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.466472303206997,
#   'bedrooms_per_room': 0.19253333333333333,
#   'population_per_household': 2.9941690962099123},
#  {'longitude': -122.21,
#   'latitude': 37.48,
#   'housing_median_age': 20.0,
#   'total_rooms': 505.0,
#   'total_bedrooms': 216.0,
#   'population': 326.0,
#   'households': 216.0,
#   'median_income': 2.9286,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 2.337962962962963,
#   'bedrooms_per_room': 0.4277227722772277,
#   'population_per_household': 1.5092592592592593},
#  {'longitude': -122.25,
#   'latitude': 37.89,
#   'housing_median_age': 41.0,
#   'total_rooms': 1125.0,
#   'total_bedrooms': 195.0,
#   'population': 356.0,
#   'households': 181.0,
#   'median_income': 6.1593,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 6.2154696132596685,
#   'bedrooms_per_room': 0.17333333333333334,
#   'population_per_household': 1.9668508287292819},
#  {'longitude': -121.36,
#   'latitude': 39.52,
#   'housing_median_age': 15.0,
#   'total_rooms': 2490.0,
#   'total_bedrooms': 527.0,
#   'population': 1229.0,
#   'households': 497.0,
#   'median_income': 2.3917,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.010060362173038,
#   'bedrooms_per_room': 0.21164658634538153,
#   'population_per_household': 2.4728370221327967},
#  {'longitude': -122.18,
#   'latitude': 37.41,
#   'housing_median_age': 21.0,
#   'total_rooms': 1034.0,
#   'total_bedrooms': 117.0,
#   'population': 323.0,
#   'households': 117.0,
#   'median_income': 10.7237,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 8.837606837606838,
#   'bedrooms_per_room': 0.11315280464216634,
#   'population_per_household': 2.7606837606837606},
#  {'longitude': -122.33,
#   'latitude': 37.99,
#   'housing_median_age': 4.0,
#   'total_rooms': 3999.0,
#   'total_bedrooms': 1079.0,
#   'population': 1591.0,
#   'households': 887.0,
#   'median_income': 3.911,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.508455467869222,
#   'bedrooms_per_room': 0.2698174543635909,
#   'population_per_household': 1.7936865839909808},
#  {'longitude': -118.3,
#   'latitude': 34.19,
#   'housing_median_age': 14.0,
#   'total_rooms': 3615.0,
#   'total_bedrooms': 913.0,
#   'population': 1924.0,
#   'households': 852.0,
#   'median_income': 3.5083,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.242957746478873,
#   'bedrooms_per_room': 0.25255878284923927,
#   'population_per_household': 2.2582159624413145},
#  {'longitude': -122.0,
#   'latitude': 37.58,
#   'housing_median_age': 6.0,
#   'total_rooms': 4405.0,
#   'total_bedrooms': 717.0,
#   'population': 2071.0,
#   'households': 688.0,
#   'median_income': 5.8151,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.402616279069767,
#   'bedrooms_per_room': 0.16276958002270148,
#   'population_per_household': 3.010174418604651},
#  {'longitude': -118.31,
#   'latitude': 34.02,
#   'housing_median_age': 23.0,
#   'total_rooms': 1703.0,
#   'total_bedrooms': 397.0,
#   'population': 1333.0,
#   'households': 361.0,
#   'median_income': 1.3187,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.717451523545706,
#   'bedrooms_per_room': 0.23311802701115678,
#   'population_per_household': 3.6925207756232687},
#  {'longitude': -122.02,
#   'latitude': 37.39,
#   'housing_median_age': 35.0,
#   'total_rooms': 2297.0,
#   'total_bedrooms': 497.0,
#   'population': 1428.0,
#   'households': 497.0,
#   'median_income': 4.7431,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.621730382293762,
#   'bedrooms_per_room': 0.21636917718763604,
#   'population_per_household': 2.8732394366197185},
#  {'longitude': -121.49,
#   'latitude': 38.47,
#   'housing_median_age': 26.0,
#   'total_rooms': 6121.0,
#   'total_bedrooms': 1185.0,
#   'population': 4224.0,
#   'households': 1105.0,
#   'median_income': 2.3496,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.539366515837104,
#   'bedrooms_per_room': 0.1935958176768502,
#   'population_per_household': 3.8226244343891405},
#  {'longitude': -117.49,
#   'latitude': 33.98,
#   'housing_median_age': 17.0,
#   'total_rooms': 2727.0,
#   'total_bedrooms': 462.0,
#   'population': 1691.0,
#   'households': 448.0,
#   'median_income': 4.8371,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.087053571428571,
#   'bedrooms_per_room': 0.1694169416941694,
#   'population_per_household': 3.7745535714285716},
#  {'longitude': -121.85,
#   'latitude': 37.39,
#   'housing_median_age': 15.0,
#   'total_rooms': 8748.0,
#   'total_bedrooms': 1547.0,
#   'population': 4784.0,
#   'households': 1524.0,
#   'median_income': 5.8322,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.74015748031496,
#   'bedrooms_per_room': 0.17684042066758116,
#   'population_per_household': 3.1391076115485563},
#  {'longitude': -120.45,
#   'latitude': 34.65,
#   'housing_median_age': 25.0,
#   'total_rooms': 980.0,
#   'total_bedrooms': 276.0,
#   'population': 896.0,
#   'households': 245.0,
#   'median_income': 2.0,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.0,
#   'bedrooms_per_room': 0.2816326530612245,
#   'population_per_household': 3.657142857142857},
#  {'longitude': -122.69,
#   'latitude': 38.46,
#   'housing_median_age': 32.0,
#   'total_rooms': 2970.0,
#   'total_bedrooms': 504.0,
#   'population': 1117.0,
#   'households': 512.0,
#   'median_income': 5.0,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.80078125,
#   'bedrooms_per_room': 0.1696969696969697,
#   'population_per_household': 2.181640625},
#  {'longitude': -118.49,
#   'latitude': 34.06,
#   'housing_median_age': 42.0,
#   'total_rooms': 2861.0,
#   'total_bedrooms': 360.0,
#   'population': 829.0,
#   'households': 310.0,
#   'median_income': 15.0001,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 9.229032258064516,
#   'bedrooms_per_room': 0.12583012932541068,
#   'population_per_household': 2.674193548387097},
#  {'longitude': -117.93,
#   'latitude': 34.08,
#   'housing_median_age': 36.0,
#   'total_rooms': 1788.0,
#   'total_bedrooms': 317.0,
#   'population': 1139.0,
#   'households': 320.0,
#   'median_income': 4.125,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.5875,
#   'bedrooms_per_room': 0.1772930648769575,
#   'population_per_household': 3.559375},
#  {'longitude': -119.73,
#   'latitude': 36.81,
#   'housing_median_age': 19.0,
#   'total_rooms': 1699.0,
#   'total_bedrooms': 356.0,
#   'population': 994.0,
#   'households': 368.0,
#   'median_income': 2.7778,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.616847826086956,
#   'bedrooms_per_room': 0.20953502060035314,
#   'population_per_household': 2.7010869565217392},
#  {'longitude': -122.26,
#   'latitude': 37.78,
#   'housing_median_age': 52.0,
#   'total_rooms': 970.0,
#   'total_bedrooms': 217.0,
#   'population': 528.0,
#   'households': 208.0,
#   'median_income': 3.3438,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.663461538461538,
#   'bedrooms_per_room': 0.22371134020618558,
#   'population_per_household': 2.5384615384615383},
#  {'longitude': -121.76,
#   'latitude': 36.9,
#   'housing_median_age': 44.0,
#   'total_rooms': 919.0,
#   'total_bedrooms': 309.0,
#   'population': 1321.0,
#   'households': 301.0,
#   'median_income': 2.0775,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.053156146179402,
#   'bedrooms_per_room': 0.33623503808487487,
#   'population_per_household': 4.3887043189368775},
#  {'longitude': -122.03,
#   'latitude': 37.62,
#   'housing_median_age': 32.0,
#   'total_rooms': 2964.0,
#   'total_bedrooms': 547.0,
#   'population': 1472.0,
#   'households': 527.0,
#   'median_income': 4.2468,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.624288425047438,
#   'bedrooms_per_room': 0.18454790823211875,
#   'population_per_household': 2.793168880455408},
#  {'longitude': -116.92,
#   'latitude': 32.78,
#   'housing_median_age': 21.0,
#   'total_rooms': 4192.0,
#   'total_bedrooms': 752.0,
#   'population': 2101.0,
#   'households': 710.0,
#   'median_income': 4.4306,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.904225352112676,
#   'bedrooms_per_room': 0.17938931297709923,
#   'population_per_household': 2.9591549295774646},
#  {'longitude': -117.97,
#   'latitude': 34.13,
#   'housing_median_age': 42.0,
#   'total_rooms': 683.0,
#   'total_bedrooms': 127.0,
#   'population': 541.0,
#   'households': 138.0,
#   'median_income': 3.4375,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.949275362318841,
#   'bedrooms_per_room': 0.18594436310395315,
#   'population_per_household': 3.920289855072464},
#  {'longitude': -122.0,
#   'latitude': 37.95,
#   'housing_median_age': 9.0,
#   'total_rooms': 2214.0,
#   'total_bedrooms': 256.0,
#   'population': 848.0,
#   'households': 239.0,
#   'median_income': 6.8145,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 9.263598326359833,
#   'bedrooms_per_room': 0.11562782294489611,
#   'population_per_household': 3.5481171548117154},
#  {'longitude': -118.43,
#   'latitude': 34.15,
#   'housing_median_age': 28.0,
#   'total_rooms': 6270.0,
#   'total_bedrooms': 1706.0,
#   'population': 2549.0,
#   'households': 1497.0,
#   'median_income': 3.2241,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.188376753507014,
#   'bedrooms_per_room': 0.2720893141945773,
#   'population_per_household': 1.702738810955244},
#  {'longitude': -122.03,
#   'latitude': 37.37,
#   'housing_median_age': 9.0,
#   'total_rooms': 2966.0,
#   'total_bedrooms': 770.0,
#   'population': 1430.0,
#   'households': 740.0,
#   'median_income': 3.0047,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.008108108108108,
#   'bedrooms_per_room': 0.2596089008766015,
#   'population_per_household': 1.9324324324324325},
#  {'longitude': -117.25,
#   'latitude': 32.8,
#   'housing_median_age': 35.0,
#   'total_rooms': 2281.0,
#   'total_bedrooms': 506.0,
#   'population': 1005.0,
#   'households': 496.0,
#   'median_income': 4.2296,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.598790322580645,
#   'bedrooms_per_room': 0.22183252959228408,
#   'population_per_household': 2.026209677419355},
#  {'longitude': -118.21,
#   'latitude': 33.8,
#   'housing_median_age': 41.0,
#   'total_rooms': 1251.0,
#   'total_bedrooms': 279.0,
#   'population': 1053.0,
#   'households': 278.0,
#   'median_income': 3.2778,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.5,
#   'bedrooms_per_room': 0.22302158273381295,
#   'population_per_household': 3.787769784172662},
#  {'longitude': -117.71,
#   'latitude': 33.61,
#   'housing_median_age': 26.0,
#   'total_rooms': 3046.0,
#   'total_bedrooms': 726.0,
#   'population': 888.0,
#   'households': 663.0,
#   'median_income': 2.6848,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.5942684766214175,
#   'bedrooms_per_room': 0.23834537097833225,
#   'population_per_household': 1.339366515837104},
#  {'longitude': -122.27,
#   'latitude': 37.89,
#   'housing_median_age': 52.0,
#   'total_rooms': 2640.0,
#   'total_bedrooms': 366.0,
#   'population': 973.0,
#   'households': 355.0,
#   'median_income': 7.266,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 7.436619718309859,
#   'bedrooms_per_room': 0.13863636363636364,
#   'population_per_household': 2.740845070422535},
#  {'longitude': -121.04,
#   'latitude': 37.3,
#   'housing_median_age': 6.0,
#   'total_rooms': 2657.0,
#   'total_bedrooms': 486.0,
#   'population': 1409.0,
#   'households': 392.0,
#   'median_income': 3.3824,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.778061224489796,
#   'bedrooms_per_room': 0.182913059841927,
#   'population_per_household': 3.5943877551020407},
#  {'longitude': -120.43,
#   'latitude': 38.25,
#   'housing_median_age': 13.0,
#   'total_rooms': 763.0,
#   'total_bedrooms': 161.0,
#   'population': 311.0,
#   'households': 125.0,
#   'median_income': 2.4583,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.104,
#   'bedrooms_per_room': 0.21100917431192662,
#   'population_per_household': 2.488},
#  {'longitude': -118.26,
#   'latitude': 34.13,
#   'housing_median_age': 37.0,
#   'total_rooms': 196.0,
#   'total_bedrooms': 74.0,
#   'population': 194.0,
#   'households': 68.0,
#   'median_income': 1.2188,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 2.8823529411764706,
#   'bedrooms_per_room': 0.37755102040816324,
#   'population_per_household': 2.8529411764705883},
#  {'longitude': -117.15,
#   'latitude': 32.8,
#   'housing_median_age': 41.0,
#   'total_rooms': 1413.0,
#   'total_bedrooms': 261.0,
#   'population': 1070.0,
#   'households': 259.0,
#   'median_income': 2.3578,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.455598455598456,
#   'bedrooms_per_room': 0.18471337579617833,
#   'population_per_household': 4.1312741312741315},
#  {'longitude': -118.19,
#   'latitude': 33.78,
#   'housing_median_age': 35.0,
#   'total_rooms': 1511.0,
#   'total_bedrooms': 593.0,
#   'population': 914.0,
#   'households': 539.0,
#   'median_income': 0.9318,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 2.803339517625232,
#   'bedrooms_per_room': 0.3924553275976175,
#   'population_per_household': 1.6957328385899815},
#  {'longitude': -117.15,
#   'latitude': 32.9,
#   'housing_median_age': 12.0,
#   'total_rooms': 1681.0,
#   'total_bedrooms': 381.0,
#   'population': 1050.0,
#   'households': 362.0,
#   'median_income': 4.2008,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.643646408839779,
#   'bedrooms_per_room': 0.22665080309339677,
#   'population_per_household': 2.9005524861878453},
#  {'longitude': -118.12,
#   'latitude': 33.9,
#   'housing_median_age': 35.0,
#   'total_rooms': 3478.0,
#   'total_bedrooms': 730.0,
#   'population': 1885.0,
#   'households': 673.0,
#   'median_income': 2.9375,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.167904903417534,
#   'bedrooms_per_room': 0.2098907418056354,
#   'population_per_household': 2.800891530460624},
#  {'longitude': -117.65,
#   'latitude': 33.53,
#   'housing_median_age': 7.0,
#   'total_rooms': 6814.0,
#   'total_bedrooms': 785.0,
#   'population': 2175.0,
#   'households': 681.0,
#   'median_income': 10.49,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 10.005873715124816,
#   'bedrooms_per_room': 0.11520399178162606,
#   'population_per_household': 3.193832599118943},
#  {'longitude': -118.44,
#   'latitude': 34.0,
#   'housing_median_age': 44.0,
#   'total_rooms': 1462.0,
#   'total_bedrooms': 338.0,
#   'population': 821.0,
#   'households': 341.0,
#   'median_income': 2.599,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.287390029325513,
#   'bedrooms_per_room': 0.23119015047879618,
#   'population_per_household': 2.407624633431085},
#  {'longitude': -121.25,
#   'latitude': 38.03,
#   'housing_median_age': 29.0,
#   'total_rooms': 2465.0,
#   'total_bedrooms': 327.0,
#   'population': 859.0,
#   'households': 315.0,
#   'median_income': 6.6605,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 7.825396825396825,
#   'bedrooms_per_room': 0.13265720081135904,
#   'population_per_household': 2.726984126984127},
#  {'longitude': -118.42,
#   'latitude': 34.12,
#   'housing_median_age': 27.0,
#   'total_rooms': 2089.0,
#   'total_bedrooms': 303.0,
#   'population': 654.0,
#   'households': 270.0,
#   'median_income': 12.3767,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.737037037037037,
#   'bedrooms_per_room': 0.1450454763044519,
#   'population_per_household': 2.422222222222222},
#  {'longitude': -119.27,
#   'latitude': 34.29,
#   'housing_median_age': 32.0,
#   'total_rooms': 2274.0,
#   'total_bedrooms': 406.0,
#   'population': 982.0,
#   'households': 393.0,
#   'median_income': 5.3254,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.786259541984733,
#   'bedrooms_per_room': 0.1785400175901495,
#   'population_per_household': 2.4987277353689565},
#  {'longitude': -118.42,
#   'latitude': 34.01,
#   'housing_median_age': 33.0,
#   'total_rooms': 2731.0,
#   'total_bedrooms': 535.0,
#   'population': 1280.0,
#   'households': 510.0,
#   'median_income': 4.7083,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.354901960784313,
#   'bedrooms_per_room': 0.19589893811790554,
#   'population_per_household': 2.5098039215686274},
#  {'longitude': -118.37,
#   'latitude': 34.04,
#   'housing_median_age': 25.0,
#   'total_rooms': 542.0,
#   'total_bedrooms': 161.0,
#   'population': 442.0,
#   'households': 131.0,
#   'median_income': 2.25,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.137404580152672,
#   'bedrooms_per_room': 0.29704797047970477,
#   'population_per_household': 3.3740458015267176},
#  {'longitude': -121.84,
#   'latitude': 37.38,
#   'housing_median_age': 34.0,
#   'total_rooms': 762.0,
#   'total_bedrooms': 182.0,
#   'population': 611.0,
#   'households': 193.0,
#   'median_income': 3.5625,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.948186528497409,
#   'bedrooms_per_room': 0.2388451443569554,
#   'population_per_household': 3.1658031088082903},
#  {'longitude': -119.85,
#   'latitude': 36.82,
#   'housing_median_age': 9.0,
#   'total_rooms': 3995.0,
#   'total_bedrooms': 778.0,
#   'population': 1691.0,
#   'households': 712.0,
#   'median_income': 3.3239,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.610955056179775,
#   'bedrooms_per_room': 0.19474342928660826,
#   'population_per_household': 2.375},
#  {'longitude': -121.96,
#   'latitude': 37.25,
#   'housing_median_age': 35.0,
#   'total_rooms': 1018.0,
#   'total_bedrooms': 169.0,
#   'population': 484.0,
#   'households': 174.0,
#   'median_income': 6.1648,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.850574712643678,
#   'bedrooms_per_room': 0.16601178781925344,
#   'population_per_household': 2.781609195402299},
#  {'longitude': -118.11,
#   'latitude': 33.89,
#   'housing_median_age': 35.0,
#   'total_rooms': 1139.0,
#   'total_bedrooms': 197.0,
#   'population': 772.0,
#   'households': 233.0,
#   'median_income': 4.375,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.888412017167382,
#   'bedrooms_per_room': 0.17295873573309922,
#   'population_per_household': 3.313304721030043},
#  {'longitude': -118.2,
#   'latitude': 34.04,
#   'housing_median_age': 44.0,
#   'total_rooms': 1399.0,
#   'total_bedrooms': 386.0,
#   'population': 1419.0,
#   'households': 373.0,
#   'median_income': 1.8224,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.7506702412868633,
#   'bedrooms_per_room': 0.27591136526090065,
#   'population_per_household': 3.804289544235925},
#  {'longitude': -118.1,
#   'latitude': 34.05,
#   'housing_median_age': 31.0,
#   'total_rooms': 3559.0,
#   'total_bedrooms': 734.0,
#   'population': 2975.0,
#   'households': 715.0,
#   'median_income': 3.756,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.977622377622378,
#   'bedrooms_per_room': 0.20623770722112952,
#   'population_per_household': 4.160839160839161},
#  {'longitude': -117.33,
#   'latitude': 34.06,
#   'housing_median_age': 42.0,
#   'total_rooms': 530.0,
#   'total_bedrooms': 123.0,
#   'population': 390.0,
#   'households': 124.0,
#   'median_income': 1.0469,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.274193548387097,
#   'bedrooms_per_room': 0.2320754716981132,
#   'population_per_household': 3.1451612903225805},
#  {'longitude': -122.12,
#   'latitude': 37.94,
#   'housing_median_age': 22.0,
#   'total_rooms': 4949.0,
#   'total_bedrooms': 626.0,
#   'population': 1850.0,
#   'households': 590.0,
#   'median_income': 10.4549,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 8.388135593220339,
#   'bedrooms_per_room': 0.1264902000404122,
#   'population_per_household': 3.135593220338983},
#  {'longitude': -122.42,
#   'latitude': 37.73,
#   'housing_median_age': 48.0,
#   'total_rooms': 1474.0,
#   'total_bedrooms': 308.0,
#   'population': 998.0,
#   'households': 330.0,
#   'median_income': 4.0781,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.466666666666667,
#   'bedrooms_per_room': 0.208955223880597,
#   'population_per_household': 3.0242424242424244},
#  {'longitude': -118.11,
#   'latitude': 34.01,
#   'housing_median_age': 43.0,
#   'total_rooms': 1539.0,
#   'total_bedrooms': 386.0,
#   'population': 1122.0,
#   'households': 377.0,
#   'median_income': 2.4605,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.082228116710875,
#   'bedrooms_per_room': 0.2508122157244964,
#   'population_per_household': 2.976127320954907},
#  {'longitude': -118.06,
#   'latitude': 34.11,
#   'housing_median_age': 39.0,
#   'total_rooms': 2603.0,
#   'total_bedrooms': 547.0,
#   'population': 1196.0,
#   'households': 487.0,
#   'median_income': 3.0854,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.344969199178645,
#   'bedrooms_per_room': 0.2101421436803688,
#   'population_per_household': 2.455852156057495},
#  {'longitude': -117.68,
#   'latitude': 34.14,
#   'housing_median_age': 4.0,
#   'total_rooms': 4791.0,
#   'total_bedrooms': 695.0,
#   'population': 1871.0,
#   'households': 659.0,
#   'median_income': 6.9532,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 7.2701062215478,
#   'bedrooms_per_room': 0.14506366103109997,
#   'population_per_household': 2.8391502276176026},
#  {'longitude': -117.04,
#   'latitude': 32.62,
#   'housing_median_age': 27.0,
#   'total_rooms': 1710.0,
#   'total_bedrooms': 282.0,
#   'population': 1089.0,
#   'households': 297.0,
#   'median_income': 4.6793,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.757575757575758,
#   'bedrooms_per_room': 0.1649122807017544,
#   'population_per_household': 3.6666666666666665},
#  {'longitude': -117.51,
#   'latitude': 34.0,
#   'housing_median_age': 36.0,
#   'total_rooms': 3791.0,
#   'total_bedrooms': 746.0,
#   'population': 2258.0,
#   'households': 672.0,
#   'median_income': 3.2067,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.6413690476190474,
#   'bedrooms_per_room': 0.19678185175415458,
#   'population_per_household': 3.3601190476190474},
#  {'longitude': -116.94,
#   'latitude': 32.85,
#   'housing_median_age': 31.0,
#   'total_rooms': 1293.0,
#   'total_bedrooms': 232.0,
#   'population': 599.0,
#   'households': 228.0,
#   'median_income': 4.7578,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.671052631578948,
#   'bedrooms_per_room': 0.1794276875483372,
#   'population_per_household': 2.6271929824561404},
#  {'longitude': -124.17,
#   'latitude': 41.76,
#   'housing_median_age': 20.0,
#   'total_rooms': 2673.0,
#   'total_bedrooms': 538.0,
#   'population': 1282.0,
#   'households': 514.0,
#   'median_income': 2.4605,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.200389105058366,
#   'bedrooms_per_room': 0.20127197904975683,
#   'population_per_household': 2.4941634241245136},
#  {'longitude': -121.36,
#   'latitude': 38.63,
#   'housing_median_age': 30.0,
#   'total_rooms': 2619.0,
#   'total_bedrooms': 370.0,
#   'population': 940.0,
#   'households': 359.0,
#   'median_income': 4.7283,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 7.295264623955432,
#   'bedrooms_per_room': 0.14127529591447116,
#   'population_per_household': 2.618384401114206},
#  {'longitude': -122.04,
#   'latitude': 37.37,
#   'housing_median_age': 42.0,
#   'total_rooms': 1125.0,
#   'total_bedrooms': 273.0,
#   'population': 616.0,
#   'households': 258.0,
#   'median_income': 3.6765,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.3604651162790695,
#   'bedrooms_per_room': 0.24266666666666667,
#   'population_per_household': 2.387596899224806},
#  {'longitude': -122.0,
#   'latitude': 37.23,
#   'housing_median_age': 36.0,
#   'total_rooms': 3191.0,
#   'total_bedrooms': 430.0,
#   'population': 1234.0,
#   'households': 440.0,
#   'median_income': 9.0704,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.252272727272727,
#   'bedrooms_per_room': 0.1347539956126606,
#   'population_per_household': 2.8045454545454547},
#  {'longitude': -122.25,
#   'latitude': 38.12,
#   'housing_median_age': 47.0,
#   'total_rooms': 1339.0,
#   'total_bedrooms': 298.0,
#   'population': 794.0,
#   'households': 286.0,
#   'median_income': 2.5865,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.681818181818182,
#   'bedrooms_per_room': 0.22255414488424197,
#   'population_per_household': 2.7762237762237763},
#  {'longitude': -120.35,
#   'latitude': 36.14,
#   'housing_median_age': 9.0,
#   'total_rooms': 2671.0,
#   'total_bedrooms': 647.0,
#   'population': 1484.0,
#   'households': 541.0,
#   'median_income': 1.7075,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.937153419593345,
#   'bedrooms_per_room': 0.242231374017222,
#   'population_per_household': 2.743068391866913},
#  {'longitude': -118.26,
#   'latitude': 34.02,
#   'housing_median_age': 46.0,
#   'total_rooms': 1249.0,
#   'total_bedrooms': 357.0,
#   'population': 1607.0,
#   'households': 331.0,
#   'median_income': 2.0703,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.773413897280967,
#   'bedrooms_per_room': 0.28582866293034426,
#   'population_per_household': 4.854984894259819},
#  {'longitude': -121.39,
#   'latitude': 38.62,
#   'housing_median_age': 45.0,
#   'total_rooms': 2696.0,
#   'total_bedrooms': 624.0,
#   'population': 1059.0,
#   'households': 582.0,
#   'median_income': 1.8176,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.632302405498282,
#   'bedrooms_per_room': 0.2314540059347181,
#   'population_per_household': 1.8195876288659794},
#  {'longitude': -118.19,
#   'latitude': 34.12,
#   'housing_median_age': 44.0,
#   'total_rooms': 1219.0,
#   'total_bedrooms': 324.0,
#   'population': 1036.0,
#   'households': 282.0,
#   'median_income': 4.0417,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.322695035460993,
#   'bedrooms_per_room': 0.26579163248564397,
#   'population_per_household': 3.673758865248227},
#  {'longitude': -118.5,
#   'latitude': 34.02,
#   'housing_median_age': 24.0,
#   'total_rooms': 2924.0,
#   'total_bedrooms': 1013.0,
#   'population': 1492.0,
#   'households': 943.0,
#   'median_income': 2.775,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.1007423117709436,
#   'bedrooms_per_room': 0.34644322845417236,
#   'population_per_household': 1.5821845174973488},
#  {'longitude': -117.97,
#   'latitude': 33.65,
#   'housing_median_age': 26.0,
#   'total_rooms': 2379.0,
#   'total_bedrooms': 336.0,
#   'population': 988.0,
#   'households': 346.0,
#   'median_income': 5.3674,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.875722543352601,
#   'bedrooms_per_room': 0.14123581336696092,
#   'population_per_household': 2.8554913294797686},
#  {'longitude': -118.87,
#   'latitude': 34.22,
#   'housing_median_age': 14.0,
#   'total_rooms': 3108.0,
#   'total_bedrooms': 451.0,
#   'population': 1566.0,
#   'households': 434.0,
#   'median_income': 6.2423,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.161290322580645,
#   'bedrooms_per_room': 0.1451093951093951,
#   'population_per_household': 3.608294930875576},
#  {'longitude': -118.05,
#   'latitude': 34.11,
#   'housing_median_age': 42.0,
#   'total_rooms': 3677.0,
#   'total_bedrooms': 627.0,
#   'population': 1779.0,
#   'households': 622.0,
#   'median_income': 5.1509,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.911575562700965,
#   'bedrooms_per_room': 0.1705194451998912,
#   'population_per_household': 2.860128617363344},
#  {'longitude': -118.19,
#   'latitude': 33.98,
#   'housing_median_age': 34.0,
#   'total_rooms': 1022.0,
#   'total_bedrooms': 286.0,
#   'population': 1058.0,
#   'households': 275.0,
#   'median_income': 2.6042,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.7163636363636363,
#   'bedrooms_per_room': 0.27984344422700586,
#   'population_per_household': 3.847272727272727},
#  {'longitude': -117.74,
#   'latitude': 33.85,
#   'housing_median_age': 4.0,
#   'total_rooms': 5416.0,
#   'total_bedrooms': 820.0,
#   'population': 1753.0,
#   'households': 583.0,
#   'median_income': 6.9544,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 9.289879931389365,
#   'bedrooms_per_room': 0.15140324963072377,
#   'population_per_household': 3.006861063464837},
#  {'longitude': -120.38,
#   'latitude': 37.97,
#   'housing_median_age': 47.0,
#   'total_rooms': 1060.0,
#   'total_bedrooms': 219.0,
#   'population': 496.0,
#   'households': 205.0,
#   'median_income': 2.5781,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.170731707317073,
#   'bedrooms_per_room': 0.20660377358490567,
#   'population_per_household': 2.419512195121951},
#  {'longitude': -117.25,
#   'latitude': 32.8,
#   'housing_median_age': 31.0,
#   'total_rooms': 2182.0,
#   'total_bedrooms': 630.0,
#   'population': 1069.0,
#   'households': 599.0,
#   'median_income': 2.9781,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 3.642737896494157,
#   'bedrooms_per_room': 0.2887259395050413,
#   'population_per_household': 1.7846410684474123},
#  {'longitude': -119.76,
#   'latitude': 34.44,
#   'housing_median_age': 28.0,
#   'total_rooms': 1985.0,
#   'total_bedrooms': 582.0,
#   'population': 1092.0,
#   'households': 548.0,
#   'median_income': 2.4701,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 3.622262773722628,
#   'bedrooms_per_room': 0.2931989924433249,
#   'population_per_household': 1.9927007299270072},
#  {'longitude': -117.32,
#   'latitude': 33.22,
#   'housing_median_age': 16.0,
#   'total_rooms': 1057.0,
#   'total_bedrooms': 232.0,
#   'population': 316.0,
#   'households': 221.0,
#   'median_income': 2.7417,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.782805429864253,
#   'bedrooms_per_room': 0.2194891201513718,
#   'population_per_household': 1.4298642533936652},
#  {'longitude': -118.04,
#   'latitude': 34.05,
#   'housing_median_age': 32.0,
#   'total_rooms': 1252.0,
#   'total_bedrooms': 273.0,
#   'population': 1337.0,
#   'households': 263.0,
#   'median_income': 2.6579,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.760456273764259,
#   'bedrooms_per_room': 0.21805111821086262,
#   'population_per_household': 5.083650190114068},
#  {'longitude': -118.28,
#   'latitude': 33.83,
#   'housing_median_age': 28.0,
#   'total_rooms': 880.0,
#   'total_bedrooms': 168.0,
#   'population': 717.0,
#   'households': 142.0,
#   'median_income': 4.5469,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.197183098591549,
#   'bedrooms_per_room': 0.19090909090909092,
#   'population_per_household': 5.049295774647887},
#  {'longitude': -118.31,
#   'latitude': 33.74,
#   'housing_median_age': 22.0,
#   'total_rooms': 5042.0,
#   'total_bedrooms': 974.0,
#   'population': 2260.0,
#   'households': 935.0,
#   'median_income': 4.3472,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.392513368983957,
#   'bedrooms_per_room': 0.1931773105910353,
#   'population_per_household': 2.4171122994652405},
#  {'longitude': -118.02,
#   'latitude': 33.78,
#   'housing_median_age': 28.0,
#   'total_rooms': 3375.0,
#   'total_bedrooms': 559.0,
#   'population': 1754.0,
#   'households': 554.0,
#   'median_income': 5.5446,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.092057761732852,
#   'bedrooms_per_room': 0.16562962962962963,
#   'population_per_household': 3.1660649819494586},
#  {'longitude': -117.08,
#   'latitude': 33.14,
#   'housing_median_age': 15.0,
#   'total_rooms': 1497.0,
#   'total_bedrooms': 250.0,
#   'population': 827.0,
#   'households': 239.0,
#   'median_income': 4.3846,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.2635983263598325,
#   'bedrooms_per_room': 0.16700066800267202,
#   'population_per_household': 3.4602510460251046},
#  {'longitude': -118.18,
#   'latitude': 33.77,
#   'housing_median_age': 36.0,
#   'total_rooms': 1833.0,
#   'total_bedrooms': 688.0,
#   'population': 1128.0,
#   'households': 620.0,
#   'median_income': 1.1483,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 2.956451612903226,
#   'bedrooms_per_room': 0.37534097108565195,
#   'population_per_household': 1.8193548387096774},
#  {'longitude': -118.12,
#   'latitude': 33.95,
#   'housing_median_age': 36.0,
#   'total_rooms': 2752.0,
#   'total_bedrooms': 459.0,
#   'population': 1211.0,
#   'households': 452.0,
#   'median_income': 5.0526,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 6.088495575221239,
#   'bedrooms_per_room': 0.1667877906976744,
#   'population_per_household': 2.6792035398230087},
#  {'longitude': -122.29,
#   'latitude': 37.9,
#   'housing_median_age': 52.0,
#   'total_rooms': 2657.0,
#   'total_bedrooms': 500.0,
#   'population': 1131.0,
#   'households': 489.0,
#   'median_income': 4.4286,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.433537832310838,
#   'bedrooms_per_room': 0.1881821603312006,
#   'population_per_household': 2.312883435582822},
#  {'longitude': -116.54,
#   'latitude': 33.79,
#   'housing_median_age': 18.0,
#   'total_rooms': 9374.0,
#   'total_bedrooms': 1780.0,
#   'population': 1678.0,
#   'households': 919.0,
#   'median_income': 3.9737,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 10.200217627856366,
#   'bedrooms_per_room': 0.1898869212716023,
#   'population_per_household': 1.8258977149075082},
#  {'longitude': -117.04,
#   'latitude': 32.7,
#   'housing_median_age': 7.0,
#   'total_rooms': 9311.0,
#   'total_bedrooms': 1703.0,
#   'population': 7302.0,
#   'households': 1694.0,
#   'median_income': 4.419,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.496458087367178,
#   'bedrooms_per_room': 0.1829019439372785,
#   'population_per_household': 4.310507674144038},
#  {'longitude': -118.23,
#   'latitude': 33.98,
#   'housing_median_age': 30.0,
#   'total_rooms': 2562.0,
#   'total_bedrooms': 959.0,
#   'population': 3909.0,
#   'households': 955.0,
#   'median_income': 1.9929,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 2.682722513089005,
#   'bedrooms_per_room': 0.3743169398907104,
#   'population_per_household': 4.093193717277487},
#  {'longitude': -118.15,
#   'latitude': 35.04,
#   'housing_median_age': 29.0,
#   'total_rooms': 1671.0,
#   'total_bedrooms': 368.0,
#   'population': 821.0,
#   'households': 337.0,
#   'median_income': 2.16,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.958456973293768,
#   'bedrooms_per_room': 0.22022740873728305,
#   'population_per_household': 2.43620178041543},
#  {'longitude': -117.2,
#   'latitude': 32.85,
#   'housing_median_age': 26.0,
#   'total_rooms': 2298.0,
#   'total_bedrooms': 549.0,
#   'population': 980.0,
#   'households': 555.0,
#   'median_income': 2.4207,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.140540540540541,
#   'bedrooms_per_room': 0.23890339425587467,
#   'population_per_household': 1.7657657657657657},
#  {'longitude': -118.52,
#   'latitude': 34.25,
#   'housing_median_age': 11.0,
#   'total_rooms': 7849.0,
#   'total_bedrooms': 1664.0,
#   'population': 3561.0,
#   'households': 1500.0,
#   'median_income': 4.6625,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.232666666666667,
#   'bedrooms_per_room': 0.21200152885717927,
#   'population_per_household': 2.374},
#  {'longitude': -118.03,
#   'latitude': 34.06,
#   'housing_median_age': 36.0,
#   'total_rooms': 1018.0,
#   'total_bedrooms': 305.0,
#   'population': 1307.0,
#   'households': 292.0,
#   'median_income': 2.1453,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.4863013698630136,
#   'bedrooms_per_room': 0.29960707269155207,
#   'population_per_household': 4.476027397260274},
#  {'longitude': -121.6,
#   'latitude': 39.77,
#   'housing_median_age': 26.0,
#   'total_rooms': 1503.0,
#   'total_bedrooms': 343.0,
#   'population': 699.0,
#   'households': 296.0,
#   'median_income': 1.875,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.077702702702703,
#   'bedrooms_per_room': 0.22821024617431804,
#   'population_per_household': 2.3614864864864864},
#  {'longitude': -119.13,
#   'latitude': 36.13,
#   'housing_median_age': 28.0,
#   'total_rooms': 1673.0,
#   'total_bedrooms': 385.0,
#   'population': 1434.0,
#   'households': 371.0,
#   'median_income': 2.0586,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.509433962264151,
#   'bedrooms_per_room': 0.2301255230125523,
#   'population_per_household': 3.8652291105121295},
#  {'longitude': -117.1,
#   'latitude': 32.58,
#   'housing_median_age': 23.0,
#   'total_rooms': 1662.0,
#   'total_bedrooms': 377.0,
#   'population': 1318.0,
#   'households': 386.0,
#   'median_income': 2.3,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 4.305699481865285,
#   'bedrooms_per_room': 0.22683513838748495,
#   'population_per_household': 3.4145077720207255},
#  {'longitude': -122.27,
#   'latitude': 37.88,
#   'housing_median_age': 44.0,
#   'total_rooms': 2252.0,
#   'total_bedrooms': 592.0,
#   'population': 989.0,
#   'households': 550.0,
#   'median_income': 3.0132,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.094545454545455,
#   'bedrooms_per_room': 0.26287744227353466,
#   'population_per_household': 1.798181818181818},
#  {'longitude': -118.12,
#   'latitude': 33.96,
#   'housing_median_age': 38.0,
#   'total_rooms': 1301.0,
#   'total_bedrooms': 264.0,
#   'population': 877.0,
#   'households': 275.0,
#   'median_income': 4.625,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.7309090909090905,
#   'bedrooms_per_room': 0.20292083013066872,
#   'population_per_household': 3.189090909090909},
#  {'longitude': -118.52,
#   'latitude': 34.04,
#   'housing_median_age': 42.0,
#   'total_rooms': 993.0,
#   'total_bedrooms': 130.0,
#   'population': 368.0,
#   'households': 134.0,
#   'median_income': 10.8082,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.41044776119403,
#   'bedrooms_per_room': 0.1309164149043303,
#   'population_per_household': 2.746268656716418},
#  {'longitude': -118.26,
#   'latitude': 33.85,
#   'housing_median_age': 25.0,
#   'total_rooms': 2324.0,
#   'total_bedrooms': 326.0,
#   'population': 1087.0,
#   'households': 328.0,
#   'median_income': 5.293,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 7.085365853658536,
#   'bedrooms_per_room': 0.14027538726333907,
#   'population_per_household': 3.3140243902439024},
#  {'longitude': -118.02,
#   'latitude': 33.71,
#   'housing_median_age': 23.0,
#   'total_rooms': 5554.0,
#   'total_bedrooms': 995.0,
#   'population': 2408.0,
#   'households': 936.0,
#   'median_income': 5.3886,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.933760683760684,
#   'bedrooms_per_room': 0.1791501620453727,
#   'population_per_household': 2.572649572649573},
#  {'longitude': -119.06,
#   'latitude': 34.37,
#   'housing_median_age': 32.0,
#   'total_rooms': 3885.0,
#   'total_bedrooms': 759.0,
#   'population': 2504.0,
#   'households': 736.0,
#   'median_income': 3.6453,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.278532608695652,
#   'bedrooms_per_room': 0.19536679536679535,
#   'population_per_household': 3.402173913043478},
#  {'longitude': -118.96,
#   'latitude': 36.49,
#   'housing_median_age': 24.0,
#   'total_rooms': 1268.0,
#   'total_bedrooms': 269.0,
#   'population': 636.0,
#   'households': 183.0,
#   'median_income': 1.742,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.9289617486338795,
#   'bedrooms_per_room': 0.21214511041009465,
#   'population_per_household': 3.4754098360655736},
#  {'longitude': -122.47,
#   'latitude': 37.78,
#   'housing_median_age': 52.0,
#   'total_rooms': 3021.0,
#   'total_bedrooms': 569.0,
#   'population': 1479.0,
#   'households': 514.0,
#   'median_income': 4.0208,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.877431906614786,
#   'bedrooms_per_room': 0.1883482290632241,
#   'population_per_household': 2.877431906614786},
#  {'longitude': -118.14,
#   'latitude': 33.86,
#   'housing_median_age': 36.0,
#   'total_rooms': 1703.0,
#   'total_bedrooms': 325.0,
#   'population': 845.0,
#   'households': 308.0,
#   'median_income': 5.0106,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.529220779220779,
#   'bedrooms_per_room': 0.19083969465648856,
#   'population_per_household': 2.7435064935064934},
#  {'longitude': -120.65,
#   'latitude': 35.27,
#   'housing_median_age': 27.0,
#   'total_rooms': 2034.0,
#   'total_bedrooms': 341.0,
#   'population': 768.0,
#   'households': 316.0,
#   'median_income': 4.2411,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.436708860759493,
#   'bedrooms_per_room': 0.16764995083579154,
#   'population_per_household': 2.430379746835443},
#  {'longitude': -117.96,
#   'latitude': 33.67,
#   'housing_median_age': 16.0,
#   'total_rooms': 5143.0,
#   'total_bedrooms': 652.0,
#   'population': 2209.0,
#   'households': 637.0,
#   'median_income': 7.0173,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 8.073783359497645,
#   'bedrooms_per_room': 0.12677425627065914,
#   'population_per_household': 3.467817896389325},
#  {'longitude': -121.95,
#   'latitude': 38.02,
#   'housing_median_age': 9.0,
#   'total_rooms': 3360.0,
#   'total_bedrooms': 833.0,
#   'population': 2041.0,
#   'households': 810.0,
#   'median_income': 2.1013,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.148148148148148,
#   'bedrooms_per_room': 0.24791666666666667,
#   'population_per_household': 2.5197530864197533},
#  {'longitude': -117.25,
#   'latitude': 32.73,
#   'housing_median_age': 39.0,
#   'total_rooms': 1688.0,
#   'total_bedrooms': 256.0,
#   'population': 635.0,
#   'households': 272.0,
#   'median_income': 4.5938,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.205882352941177,
#   'bedrooms_per_room': 0.15165876777251186,
#   'population_per_household': 2.3345588235294117},
#  {'longitude': -118.31,
#   'latitude': 33.83,
#   'housing_median_age': 27.0,
#   'total_rooms': 2880.0,
#   'total_bedrooms': 802.0,
#   'population': 2083.0,
#   'households': 727.0,
#   'median_income': 2.9619,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.9614855570839063,
#   'bedrooms_per_room': 0.27847222222222223,
#   'population_per_household': 2.8651994497936726},
#  {'longitude': -117.77,
#   'latitude': 33.53,
#   'housing_median_age': 32.0,
#   'total_rooms': 3116.0,
#   'total_bedrooms': 661.0,
#   'population': 1105.0,
#   'households': 543.0,
# ...
#   'rooms_per_household': 4.8,
#   'bedrooms_per_room': 0.25,
#   'population_per_household': 4.6},
#  {'longitude': -117.06,
#   'latitude': 34.87,
#   'housing_median_age': 14.0,
#   'total_rooms': 3348.0,
#   'total_bedrooms': 619.0,
#   'population': 1756.0,
#   'households': 557.0,
#   'median_income': 3.5987,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.010771992818672,
#   'bedrooms_per_room': 0.18488649940262844,
#   'population_per_household': 3.1526032315978454},
#  {'longitude': -117.18,
#   'latitude': 32.69,
#   'housing_median_age': 44.0,
#   'total_rooms': 2819.0,
#   'total_bedrooms': 514.0,
#   'population': 1258.0,
#   'households': 503.0,
#   'median_income': 4.4777,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.604373757455268,
#   'bedrooms_per_room': 0.18233416105001773,
#   'population_per_household': 2.5009940357852884},
#  {'longitude': -118.34,
#   'latitude': 34.08,
#   'housing_median_age': 52.0,
#   'total_rooms': 1430.0,
#   'total_bedrooms': 186.0,
#   'population': 547.0,
#   'households': 178.0,
#   'median_income': 10.3661,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 8.03370786516854,
#   'bedrooms_per_room': 0.13006993006993006,
#   'population_per_household': 3.0730337078651684},
#  {'longitude': -118.01,
#   'latitude': 33.96,
#   'housing_median_age': 36.0,
#   'total_rooms': 1805.0,
#   'total_bedrooms': 288.0,
#   'population': 882.0,
#   'households': 308.0,
#   'median_income': 5.3054,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.8603896103896105,
#   'bedrooms_per_room': 0.1595567867036011,
#   'population_per_household': 2.8636363636363638},
#  {'longitude': -119.0,
#   'latitude': 36.06,
#   'housing_median_age': 41.0,
#   'total_rooms': 937.0,
#   'total_bedrooms': 158.0,
#   'population': 396.0,
#   'households': 142.0,
#   'median_income': 4.0833,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.598591549295775,
#   'bedrooms_per_room': 0.16862326574172892,
#   'population_per_household': 2.788732394366197},
#  {'longitude': -118.52,
#   'latitude': 34.05,
#   'housing_median_age': 45.0,
#   'total_rooms': 1814.0,
#   'total_bedrooms': 325.0,
#   'population': 709.0,
#   'households': 311.0,
#   'median_income': 4.825,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.832797427652733,
#   'bedrooms_per_room': 0.17916207276736493,
#   'population_per_household': 2.279742765273312},
#  {'longitude': -121.76,
#   'latitude': 37.68,
#   'housing_median_age': 35.0,
#   'total_rooms': 1864.0,
#   'total_bedrooms': 357.0,
#   'population': 1189.0,
#   'households': 349.0,
#   'median_income': 4.2361,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.340974212034384,
#   'bedrooms_per_room': 0.1915236051502146,
#   'population_per_household': 3.4068767908309456},
#  {'longitude': -117.26,
#   'latitude': 34.48,
#   'housing_median_age': 6.0,
#   'total_rooms': 4632.0,
#   'total_bedrooms': 753.0,
#   'population': 1851.0,
#   'households': 694.0,
#   'median_income': 4.1933,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.674351585014409,
#   'bedrooms_per_room': 0.16256476683937823,
#   'population_per_household': 2.6671469740634004},
#  {'longitude': -120.49,
#   'latitude': 37.32,
#   'housing_median_age': 10.0,
#   'total_rooms': 1275.0,
#   'total_bedrooms': 255.0,
#   'population': 620.0,
#   'households': 240.0,
#   'median_income': 3.0263,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.3125,
#   'bedrooms_per_room': 0.2,
#   'population_per_household': 2.5833333333333335},
#  {'longitude': -121.11,
#   'latitude': 41.07,
#   'housing_median_age': 26.0,
#   'total_rooms': 1707.0,
#   'total_bedrooms': 308.0,
#   'population': 761.0,
#   'households': 250.0,
#   'median_income': 2.7188,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.828,
#   'bedrooms_per_room': 0.18043350908025776,
#   'population_per_household': 3.044},
#  {'longitude': -117.23,
#   'latitude': 34.13,
#   'housing_median_age': 10.0,
#   'total_rooms': 1145.0,
#   'total_bedrooms': 293.0,
#   'population': 726.0,
#   'households': 251.0,
#   'median_income': 1.645,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.561752988047809,
#   'bedrooms_per_room': 0.25589519650655024,
#   'population_per_household': 2.8924302788844622},
#  {'longitude': -120.62,
#   'latitude': 38.71,
#   'housing_median_age': 10.0,
#   'total_rooms': 6305.0,
#   'total_bedrooms': 1150.0,
#   'population': 2597.0,
#   'households': 921.0,
#   'median_income': 4.0197,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.845819761129207,
#   'bedrooms_per_room': 0.1823949246629659,
#   'population_per_household': 2.819761129207383},
#  {'longitude': -122.24,
#   'latitude': 37.79,
#   'housing_median_age': 47.0,
#   'total_rooms': 1372.0,
#   'total_bedrooms': 395.0,
#   'population': 1237.0,
#   'households': 303.0,
#   'median_income': 2.125,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.528052805280528,
#   'bedrooms_per_room': 0.2879008746355685,
#   'population_per_household': 4.082508250825082},
#  {'longitude': -122.19,
#   'latitude': 37.48,
#   'housing_median_age': 38.0,
#   'total_rooms': 1300.0,
#   'total_bedrooms': 269.0,
#   'population': 608.0,
#   'households': 292.0,
#   'median_income': 4.5568,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 4.4520547945205475,
#   'bedrooms_per_room': 0.20692307692307693,
#   'population_per_household': 2.0821917808219177},
#  {'longitude': -117.54,
#   'latitude': 34.55,
#   'housing_median_age': 5.0,
#   'total_rooms': 2949.0,
#   'total_bedrooms': 671.0,
#   'population': 1620.0,
#   'households': 530.0,
#   'median_income': 2.9479,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.564150943396227,
#   'bedrooms_per_room': 0.2275347575449305,
#   'population_per_household': 3.056603773584906},
#  {'longitude': -118.27,
#   'latitude': 34.16,
#   'housing_median_age': 48.0,
#   'total_rooms': 1301.0,
#   'total_bedrooms': 253.0,
#   'population': 637.0,
#   'households': 260.0,
#   'median_income': 4.3438,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.003846153846154,
#   'bedrooms_per_room': 0.19446579554189086,
#   'population_per_household': 2.45},
#  {'longitude': -118.2,
#   'latitude': 33.92,
#   'housing_median_age': 36.0,
#   'total_rooms': 414.0,
#   'total_bedrooms': 104.0,
#   'population': 477.0,
#   'households': 130.0,
#   'median_income': 3.6719,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.1846153846153844,
#   'bedrooms_per_room': 0.25120772946859904,
#   'population_per_household': 3.669230769230769},
#  {'longitude': -121.72,
#   'latitude': 37.98,
#   'housing_median_age': 5.0,
#   'total_rooms': 7105.0,
#   'total_bedrooms': 1143.0,
#   'population': 3523.0,
#   'households': 1088.0,
#   'median_income': 5.0468,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.530330882352941,
#   'bedrooms_per_room': 0.16087262491203377,
#   'population_per_household': 3.2380514705882355},
#  {'longitude': -122.2,
#   'latitude': 39.53,
#   'housing_median_age': 22.0,
#   'total_rooms': 3265.0,
#   'total_bedrooms': 658.0,
#   'population': 1647.0,
#   'households': 594.0,
#   'median_income': 2.3566,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.4966329966329965,
#   'bedrooms_per_room': 0.201531393568147,
#   'population_per_household': 2.772727272727273},
#  {'longitude': -122.01,
#   'latitude': 37.59,
#   'housing_median_age': 2.0,
#   'total_rooms': 838.0,
#   'total_bedrooms': 295.0,
#   'population': 240.0,
#   'households': 149.0,
#   'median_income': 2.875,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.624161073825503,
#   'bedrooms_per_room': 0.3520286396181384,
#   'population_per_household': 1.610738255033557},
#  {'longitude': -118.66,
#   'latitude': 34.1,
#   'housing_median_age': 12.0,
#   'total_rooms': 2560.0,
#   'total_bedrooms': 365.0,
#   'population': 907.0,
#   'households': 366.0,
#   'median_income': 10.076,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.994535519125683,
#   'bedrooms_per_room': 0.142578125,
#   'population_per_household': 2.478142076502732},
#  {'longitude': -118.3,
#   'latitude': 34.08,
#   'housing_median_age': 32.0,
#   'total_rooms': 2880.0,
#   'total_bedrooms': 1063.0,
#   'population': 3646.0,
#   'households': 1028.0,
#   'median_income': 2.3846,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 2.801556420233463,
#   'bedrooms_per_room': 0.36909722222222224,
#   'population_per_household': 3.546692607003891},
#  {'longitude': -117.3,
#   'latitude': 34.54,
#   'housing_median_age': 31.0,
#   'total_rooms': 1174.0,
#   'total_bedrooms': 360.0,
#   'population': 1161.0,
#   'households': 328.0,
#   'median_income': 1.06,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 3.5792682926829267,
#   'bedrooms_per_room': 0.30664395229982966,
#   'population_per_household': 3.5396341463414633},
#  {'longitude': -122.42,
#   'latitude': 37.78,
#   'housing_median_age': 27.0,
#   'total_rooms': 1728.0,
#   'total_bedrooms': 884.0,
#   'population': 1211.0,
#   'households': 752.0,
#   'median_income': 0.8543,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 2.297872340425532,
#   'bedrooms_per_room': 0.5115740740740741,
#   'population_per_household': 1.610372340425532},
#  {'longitude': -121.32,
#   'latitude': 37.95,
#   'housing_median_age': 36.0,
#   'total_rooms': 747.0,
#   'total_bedrooms': 189.0,
#   'population': 338.0,
#   'households': 145.0,
#   'median_income': 1.7885,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 5.151724137931034,
#   'bedrooms_per_room': 0.25301204819277107,
#   'population_per_household': 2.331034482758621},
#  {'longitude': -121.3,
#   'latitude': 38.25,
#   'housing_median_age': 27.0,
#   'total_rooms': 2475.0,
#   'total_bedrooms': 548.0,
#   'population': 1703.0,
#   'households': 517.0,
#   'median_income': 2.5727,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.787234042553192,
#   'bedrooms_per_room': 0.22141414141414142,
#   'population_per_household': 3.2940038684719535},
#  {'longitude': -117.19,
#   'latitude': 32.82,
#   'housing_median_age': 34.0,
#   'total_rooms': 3850.0,
#   'total_bedrooms': 608.0,
#   'population': 1619.0,
#   'households': 602.0,
#   'median_income': 5.0465,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.395348837209302,
#   'bedrooms_per_room': 0.15792207792207794,
#   'population_per_household': 2.6893687707641196},
#  {'longitude': -117.67,
#   'latitude': 35.64,
#   'housing_median_age': 6.0,
#   'total_rooms': 2115.0,
#   'total_bedrooms': 342.0,
#   'population': 927.0,
#   'households': 337.0,
#   'median_income': 6.1935,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 6.275964391691395,
#   'bedrooms_per_room': 0.16170212765957448,
#   'population_per_household': 2.750741839762611},
#  {'longitude': -120.97,
#   'latitude': 37.68,
#   'housing_median_age': 16.0,
#   'total_rooms': 2493.0,
#   'total_bedrooms': 535.0,
#   'population': 1370.0,
#   'households': 504.0,
#   'median_income': 3.3368,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.946428571428571,
#   'bedrooms_per_room': 0.21460088247091857,
#   'population_per_household': 2.7182539682539684},
#  {'longitude': -118.13,
#   'latitude': 33.79,
#   'housing_median_age': 36.0,
#   'total_rooms': 1245.0,
#   'total_bedrooms': 211.0,
#   'population': 508.0,
#   'households': 221.0,
#   'median_income': 5.3441,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 5.633484162895928,
#   'bedrooms_per_room': 0.16947791164658635,
#   'population_per_household': 2.2986425339366514},
#  {'longitude': -118.18,
#   'latitude': 34.1,
#   'housing_median_age': 10.0,
#   'total_rooms': 1940.0,
#   'total_bedrooms': 445.0,
#   'population': 763.0,
#   'households': 412.0,
#   'median_income': 4.975,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.70873786407767,
#   'bedrooms_per_room': 0.22938144329896906,
#   'population_per_household': 1.8519417475728155},
#  {'longitude': -118.21,
#   'latitude': 33.97,
#   'housing_median_age': 43.0,
#   'total_rooms': 1751.0,
#   'total_bedrooms': 400.0,
#   'population': 1558.0,
#   'households': 379.0,
#   'median_income': 3.0313,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.620052770448549,
#   'bedrooms_per_room': 0.2284408909194746,
#   'population_per_household': 4.110817941952506},
#  {'longitude': -118.25,
#   'latitude': 33.95,
#   'housing_median_age': 25.0,
#   'total_rooms': 764.0,
#   'total_bedrooms': 200.0,
#   'population': 801.0,
#   'households': 220.0,
#   'median_income': 1.1384,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 3.4727272727272727,
#   'bedrooms_per_room': 0.2617801047120419,
#   'population_per_household': 3.640909090909091},
#  {'longitude': -122.06,
#   'latitude': 37.63,
#   'housing_median_age': 23.0,
#   'total_rooms': 1939.0,
#   'total_bedrooms': 356.0,
#   'population': 841.0,
#   'households': 364.0,
#   'median_income': 3.3611,
#   'ocean_proximity': 'NEAR BAY',
#   'rooms_per_household': 5.326923076923077,
#   'bedrooms_per_room': 0.18359979370809695,
#   'population_per_household': 2.3104395604395602},
#  {'longitude': -118.52,
#   'latitude': 34.01,
#   'housing_median_age': 25.0,
#   'total_rooms': 2757.0,
#   'total_bedrooms': 738.0,
#   'population': 1014.0,
#   'households': 633.0,
#   'median_income': 3.1433,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.355450236966824,
#   'bedrooms_per_room': 0.2676822633297062,
#   'population_per_household': 1.6018957345971565},
#  {'longitude': -118.11,
#   'latitude': 34.08,
#   'housing_median_age': 42.0,
#   'total_rooms': 3172.0,
#   'total_bedrooms': 644.0,
#   'population': 1829.0,
#   'households': 642.0,
#   'median_income': 3.3966,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.940809968847352,
#   'bedrooms_per_room': 0.2030264817150063,
#   'population_per_household': 2.8489096573208723},
#  {'longitude': -117.21,
#   'latitude': 32.84,
#   'housing_median_age': 34.0,
#   'total_rooms': 2158.0,
#   'total_bedrooms': 366.0,
#   'population': 1046.0,
#   'households': 335.0,
#   'median_income': 4.5402,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.441791044776119,
#   'bedrooms_per_room': 0.1696014828544949,
#   'population_per_household': 3.1223880597014926},
#  {'longitude': -118.38,
#   'latitude': 34.02,
#   'housing_median_age': 31.0,
#   'total_rooms': 1893.0,
#   'total_bedrooms': 450.0,
#   'population': 819.0,
#   'households': 426.0,
#   'median_income': 4.3077,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 4.443661971830986,
#   'bedrooms_per_room': 0.23771790808240886,
#   'population_per_household': 1.9225352112676057},
#  {'longitude': -117.95,
#   'latitude': 34.02,
#   'housing_median_age': 22.0,
#   'total_rooms': 1919.0,
#   'total_bedrooms': 411.0,
#   'population': 1203.0,
#   'households': 363.0,
#   'median_income': 4.2578,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.2865013774104685,
#   'bedrooms_per_room': 0.21417404898384576,
#   'population_per_household': 3.3140495867768593},
#  {'longitude': -119.8,
#   'latitude': 36.02,
#   'housing_median_age': 20.0,
#   'total_rooms': 156.0,
#   'total_bedrooms': 39.0,
#   'population': 171.0,
#   'households': 37.0,
#   'median_income': 3.05,
#   'ocean_proximity': 'INLAND',
#   'rooms_per_household': 4.216216216216216,
#   'bedrooms_per_room': 0.25,
#   'population_per_household': 4.621621621621622},
#  {'longitude': -120.41,
#   'latitude': 34.86,
#   'housing_median_age': 15.0,
#   'total_rooms': 978.0,
#   'total_bedrooms': 187.0,
#   'population': 407.0,
#   'households': 182.0,
#   'median_income': 4.375,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.373626373626373,
#   'bedrooms_per_room': 0.19120654396728015,
#   'population_per_household': 2.2362637362637363},
#  {'longitude': -122.46,
#   'latitude': 37.72,
#   'housing_median_age': 45.0,
#   'total_rooms': 2399.0,
#   'total_bedrooms': 419.0,
#   'population': 1225.0,
#   'households': 399.0,
#   'median_income': 4.0855,
#   'ocean_proximity': 'NEAR OCEAN',
#   'rooms_per_household': 6.012531328320802,
#   'bedrooms_per_room': 0.17465610671112963,
#   'population_per_household': 3.0701754385964914},
#  {'longitude': -117.92,
#   'latitude': 34.09,
#   'housing_median_age': 35.0,
#   'total_rooms': 1810.0,
#   'total_bedrooms': 318.0,
#   'population': 1164.0,
#   'households': 332.0,
#   'median_income': 5.0123,
#   'ocean_proximity': '<1H OCEAN',
#   'rooms_per_household': 5.451807228915663,
#   'bedrooms_per_room': 0.17569060773480663,
#   'population_per_household': 3.5060240963855422},
#  ...]

# %%
dv = DictVectorizer(sparse=False)

# %%
dv.fit(train_dicts)
# Out:
# DictVectorizer(sparse=False)

# %%
dv.get_feature_names()
# Out:
# /Users/nazymguliyev/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['bedrooms_per_room',
#  'households',
#  'housing_median_age',
#  'latitude',
#  'longitude',
#  'median_income',
#  'ocean_proximity=<1H OCEAN',
#  'ocean_proximity=INLAND',
#  'ocean_proximity=ISLAND',
#  'ocean_proximity=NEAR BAY',
#  'ocean_proximity=NEAR OCEAN',
#  'population',
#  'population_per_household',
#  'rooms_per_household',
#  'total_bedrooms',
#  'total_rooms']

# %%
X_train = dv.transform(train_dicts)

# %%
X_train.shape
# Out:
# (12384, 16)

# %%
model = LogisticRegression(solver="liblinear", C=1.0, max_iter=1000, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
y_pred = model.predict(X_train)

# %%
(y_pred == y_train).mean()
# Out:
# 0.8309916020671835

# %% [markdown]
# ## Question 5
